# %% [markdown]
# look at what triggers a stock to enter and leave the portfolio

# %%
import seaborn as sns
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import pandas as pd
import numpy as np 
import twoSig_comp as ts
import data_utils as du

from sklearn.linear_model import LogisticRegression

# %%
reload(ts)
ss = ts.TwoSig(fn='/Users/leiyao/data/kaggle_2sig/train_small.h5')
ss._add_enter_exit_time()
df = ss._df

# %%
ef1 = df.pivot(index='timestamp', columns='id', values='just_enter')
ef2 = df.pivot(index='timestamp', columns='id', values='just_enter')

# %%
rets = df.pivot(index='timestamp', columns='id', values='y')

# %%
xx = ef.corr()

# %%
xx
# Out:
# id     0      7     10    11    12     13     15     16     20     22    ...   \
# id                                                                       ...
# 0     1.000 -0.002   NaN   NaN   NaN -0.002 -0.002 -0.002  1.000 -0.002  ...
# 7    -0.002  1.000   NaN   NaN   NaN  1.000 -0.002 -0.002 -0.002 -0.002  ...
# 10      NaN    NaN   NaN   NaN   NaN    NaN    NaN    NaN    NaN    NaN  ...
# 11      NaN    NaN   NaN   NaN   NaN    NaN    NaN    NaN    NaN    NaN  ...
# 12      NaN    NaN   NaN   NaN   NaN    NaN    NaN    NaN    NaN    NaN  ...
# 13   -0.002  1.000   NaN   NaN   NaN  1.000 -0.002 -0.002 -0.002 -0.002  ...
# 15   -0.002 -0.002   NaN   NaN   NaN -0.002  1.000 -0.002 -0.002 -0.002  ...
# 16   -0.002 -0.002   NaN   NaN   NaN -0.002 -0.002  1.000 -0.002 -0.002  ...
# 20    1.000 -0.002   NaN   NaN   NaN -0.002 -0.002 -0.002  1.000 -0.002  ...
# 22   -0.002 -0.002   NaN   NaN   NaN -0.002 -0.002 -0.002 -0.002  1.000  ...
# ...

# %%
rets[[0, 20]].cumsum().plot()
